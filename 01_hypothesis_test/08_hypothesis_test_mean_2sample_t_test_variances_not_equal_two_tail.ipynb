# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %%
from scipy import stats
metro= [3,7,25,10,15,6,12,25,15,7]
rural =[48,44,40,38,33,21,20,12,1,18]
test_stat = stats.ttest_ind(metro,rural,equal_var=False)

#Critical t value
cr_value = stats.t.ppf(0.025,13)  # aplha by2 , dof (See above calculation)

print(test_stat)
print(cr_value)
# Out:
# Ttest_indResult(statistic=-2.7669395785560558, pvalue=0.015827284816100885)
# -2.160368656461013
