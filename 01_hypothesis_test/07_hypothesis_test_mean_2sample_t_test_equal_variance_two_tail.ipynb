# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Given 

alpha =0.05 

x1_bar = 92.255 ; x2_bar = 92.733
s_1 = 2.39 ; s_2 = 2.98

n1=n2=8

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
from scipy import stats
a = [91.5,94.18,92.18,95.39,91.79,89.07,94.72,89.21]
b= [89.19,90.95,90.46,93.21,97.19,97.04,91.07,92.75]
stats.ttest_ind(a,b,equal_var = True)
# Out:
# Ttest_indResult(statistic=-0.3535908643461798, pvalue=0.7289136186068217)

# %%
stats.t.ppf(alpha/2,14)
# Out:
# -2.1447866879169277

# %% [markdown]
# # The test statistic falls within the acceptance region , Hence we are fail to reject the NULL HYPOTHESIS.
