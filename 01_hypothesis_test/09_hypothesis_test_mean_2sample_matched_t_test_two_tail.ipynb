# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# <h1 style="color:green">Theory:</h1>
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
from scipy import stats
KARL = [1.186,1.151,1.322,1.339,1.2,1.402,1.365,1.537,1.559]
LEH = [1.061,0.992,1.063,1.062,1.065,1.178,1.037,1.086,1.052]

test_stat = stats.ttest_rel(KARL,LEH)

print(test_stat)

# Critical T value
stats.t.ppf(0.025,8)
# Out:
# Ttest_relResult(statistic=6.0819394375848255, pvalue=0.00029529546278604066)
# -2.306004135033371
