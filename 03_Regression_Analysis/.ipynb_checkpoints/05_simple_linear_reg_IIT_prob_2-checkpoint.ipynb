# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_excel(r"D:\ERA_ML\IIT Roorkee\Dataset\week_6\Important Data-20220425T103808Z-001\Important Data\HARDNESS.xls")

# %%
data
# Out:
#     Tensile strength  Hardness
# 0               53.0     29.31
# 1               70.2     34.86
# 2               84.3     36.82
# 3               55.3     30.12
# 4               78.5     34.02
# 5               63.5     30.82
# 6               71.4     35.40
# 7               53.4     31.26
# 8               82.5     32.18
# 9               67.3     33.42
# 10              69.5     37.69
# 11              73.0     34.88
# 12              55.7     24.66
# 13              85.8     34.76
# 14              95.4     38.02
# 15              51.1     25.68
# 16              74.4     25.81
# 17              54.1     26.46
# 18              77.8     28.67
# 19              52.4     24.64
# 20              69.1     25.77
# 21              53.5     23.69
# 22              64.3     28.65
# 23              82.7     32.38
# 24              55.7     23.21
# 25              70.5     34.00
# 26              87.5     34.47
# 27              50.7     29.25
# 28              72.3     28.71
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = data['Hardness'].values.reshape(-1,1)
y = data['Tensile strength'].values.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state = 88)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((28, 1), (7, 1), (28, 1), (7, 1))

# %%
len(x_train)
# Out:
# 28

# %%
len(x_test)
# Out:
# 7

# %%
x_train
# Out:
# array([[38.02],
#        [34.76],
#        [32.18],
#        [29.31],
#        [23.69],
#        [30.12],
#        [27.65],
#        [29.25],
#        [35.4 ],
#        [27.99],
#        [28.67],
#        [31.26],
#        [34.02],
#        [34.88],
#        [29.25],
#        [36.82],
#        [34.47],
#        [24.66],
#        [28.71],
#        [25.81],
#        [34.86],
#        [30.82],
#        [25.77],
#        [37.69],
#        [26.46],
#        [25.68],
#        [31.85],
#        [23.21]])

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# array([7.045691])

# %%
reg.coef_
# Out:
# array([[1.99777401]])

# %% [markdown]
# tensile_strehgth = 7.045 + 1.997 * hardness
#
# Each one unit of increase in hardness will increase the tensile strength by 7.045.

# %%
y_predict = reg.predict(x_test)

# %%
y_predict

# %%
mean_squared_error(y_test, y_predict)

# %%
reg.score(x_test, y_test)

# %%
reg.score(x_train, y_train)

# %%
import seaborn as sns

ind_var = df['Hardness']
dep_var = df['Tensile strength']
sns.scatterplot(x=ind_var,y=dep_var)
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Tensile strength'>
