# %% [markdown]
# ### Whatever we calculate using the data is sample slope , sample intercept
#
# ### At population level, whether it is same slope or not has to be verfied using significant test like T test or F test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
# T test 

# Step 1 : Hypothesis 
# H0: beta_1 = 0 (Slope is zero , No relationship b/w independednt and dependent variables)
# Ha : beta_1 !=0
# Two tailed t test 

#Step 2 : Significance level 
alpha = 0.05

#Step 3 : Decision rule 
#p_value <=alpha/2
# -t_crit<t_test<t_crit

# Calculate test statistics
# standard_error = root_mean_square_error = sqrt(MSE)=sqrt(SSE/dof)= sqrt(SSE/n-k-1)  
# Where k is no of independent variable

#t = b1-beta_1/(standard_error)

# %% [markdown]
# # Calculate test statistics

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression as LR
import seaborn as sns

# %%
tbl = pd.read_excel(r'D:\ERA_ML\IIT Roorkee\Dataset\week_6\Important Data-20220425T103808Z-001\Important Data\regr.xlsx')
tbl
# Out:
#    TV Ads  car Sold
# 0       1        14
# 1       3        24
# 2       2        18
# 3       1        17
# 4       3        27

# %%
t=tbl['TV Ads']
c=tbl['car Sold']

import statsmodels.regression.linear_model as sm
import statsmodels.api as s
t = s.add_constant(t)
model = sm.OLS(c,t)
res =model.fit()
res.summary()
# Out:
# C:\Users\Z028726\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               car Sold   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     21.43
# Date:                Thu, 12 May 2022   Prob (F-statistic):             0.0190
# Time:                        06:40:52   Log-Likelihood:                -9.6687
# No. Observations:                   5   AIC:                             23.34
# Df Residuals:                       3   BIC:                             22.56
# Df Model:                           1
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Other way

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # F test
#
# ##### When we have to compare two or more independent variable we should do F test

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
